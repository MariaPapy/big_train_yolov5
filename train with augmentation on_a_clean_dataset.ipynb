# %%
from google.colab import drive
drive.mount('/content/drive')
print('------------------------------------------------------Подключено к гугл диску')


# %cd yolov5/
# !pip install -r requirements.txt
print('-----------------------------------------------------Установлены нужные библиотеки')


import zipfile
zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/train.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")


zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/augmented_val.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")

print('---------------------------------------------------Все подготовлено, можно запускать обучение')
# Out:
# Mounted at /content/drive
# ------------------------------------------------------Подключено к гугл диску
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.12 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (11858/11858), done.
# -----------------------------------------------------Склонирована yolov5x
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 1024 --batch 16 --epochs 100 --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/drive/MyDrive/Car_Plate_Dataset/yolov5x.pt' --cache --device 0 --patience 20 --optimizer Adam
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   with torch.cuda.amp.autocast(amp):
#         3/4        13G    0.02629   0.005578          0         31        512:   6% 74/1282 [00:59<16:17,  1.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4        13G    0.02624   0.005586          0         38        512:   6% 75/1282 [01:00<15:43,  1.28it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4        13G    0.02621   0.005584          0         34        512:   6% 76/1282 [01:00<15:18,  1.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python val.py --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/yolov5/runs/train/exp4/weights/best.pt' --img 896 --batch 8 --conf 0.25 --iou 0.45 --save-txt --project runs/val --name exp
# Out:
# val: data=/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml, weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], batch_size=8, imgsz=896, conf_thres=0.25, iou_thres=0.45, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.25 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# val: Scanning /content/val/labels.cache... 2563 images, 0 backgrounds, 0 corrupt: 100% 2563/2563 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 321/321 [04:11<00:00,  1.28it/s]
# ...
