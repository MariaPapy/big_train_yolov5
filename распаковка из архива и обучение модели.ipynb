# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.11 MiB | 15.47 MiB/s, done.
# Resolving deltas: 100% (11861/11861), done.

# %%
# %cd yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 51.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import zipfile

zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/train.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")
# Out:
# Файл /content/drive/MyDrive/Car_Plate_Dataset/train.zip успешно распакован в /content/

# %%
zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/val.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")
# Out:
# Файл /content/drive/MyDrive/Car_Plate_Dataset/val.zip успешно распакован в /content/

# %%
zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/test.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")
# Out:
# Файл /content/drive/MyDrive/Car_Plate_Dataset/test.zip успешно распакован в /content/

# %%
# !python train.py --img 896 --batch 8 --epochs 1 --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/drive/MyDrive/Car_Plate_Dataset/yolov5x.pt' --nosave --cache
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#         0/0      13.3G     0.1076    0.03022          0         14        896:   4% 96/2564 [02:01<49:46,  1.21s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/0      13.3G     0.1074    0.03016          0         14        896:   4% 97/2564 [02:02<49:22,  1.20s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/0      13.3G     0.1073    0.03014          0         19        896:   4% 98/2564 [02:03<48:58,  1.19s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python val.py --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/yolov5/runs/train/exp2/weights/best.pt' --img 896 --batch 8 --conf 0.25 --iou 0.45 --save-txt --project runs/val --name exp
# Out:
# val: data=/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=8, imgsz=896, conf_thres=0.25, iou_thres=0.45, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.25 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# val: Scanning /content/val/labels.cache... 2563 images, 0 backgrounds, 0 corrupt: 100% 2563/2563 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 321/321 [04:22<00:00,  1.22it/s]
# ...
