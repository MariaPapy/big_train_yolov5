# %%
from google.colab import drive
drive.mount('/content/drive')
print('------------------------------------------------------Подключено к гугл диску')


# !git clone https://github.com/ultralytics/yolov5.git
print('-----------------------------------------------------Склонирована yolov5x')


# %cd yolov5/
# !pip install -r requirements.txt
print('-----------------------------------------------------Установлены нужные библиотеки')


import zipfile
zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/train.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")

zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/val.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")


zip_path = "/content/drive/MyDrive/Car_Plate_Dataset/test.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Файл {zip_path} успешно распакован в {extract_path}")

print('---------------------------------------------------Все подготовлено, можно запускать обучение')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ------------------------------------------------------Подключено к гугл диску
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 17.05 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# -----------------------------------------------------Склонирована yolov5x
# /content/yolov5/yolov5/yolov5
# ...
# -----------------------------------------------------Установлены нужные библиотеки
# Файл /content/drive/MyDrive/Car_Plate_Dataset/train.zip успешно распакован в /content/
# Файл /content/drive/MyDrive/Car_Plate_Dataset/val.zip успешно распакован в /content/
# Файл /content/drive/MyDrive/Car_Plate_Dataset/test.zip успешно распакован в /content/
# ...

# %%
# !python train.py --img 1024 --batch 16 --epochs 100 --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/drive/MyDrive/Car_Plate_Dataset/yolov5x.pt' --cache --device 0 --patience 20 --optimizer Adam
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-24 18:26:50.203137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740421610.452256    3627 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python val.py --data '/content/drive/MyDrive/Car_Plate_Dataset/dataset_car.yaml' --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 896 --batch 8 --conf 0.25 --iou 0.45 --save-txt --project runs/val --name exp
# Out:
# python3: can't open file '/content/val.py': [Errno 2] No such file or directory
